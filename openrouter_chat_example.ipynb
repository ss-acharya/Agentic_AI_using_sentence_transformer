# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
# Initialize the OpenAI client, pointing it to OpenRouter's API base URL
client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key='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',
    # Optional: Add default headers for tracking on OpenRouter's site
    default_headers={
        "HTTP-Referer": "https://your-app-url.com",  # Replace with your app's URL
        "X-Title": "Your App Name"  # Replace with your app's name
    }
)

# %%
# Example: Create a chat completion
try:
    chat_completion = client.chat.completions.create(
        model="mistralai/mistral-small-3.2-24b-instruct:free",  # Or specify a specific model like "anthropic/claude-3-haiku"
        messages=[
            {"role": "user", "content": "What is the capital of Germany (in German)?"},
        ]
    )

    print(chat_completion.choices[0].message.content)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# The capital of Germany is Berlin. In German, it is called "Berlin."

# %%
# Example: Create a chat completion
try:
    chat_completion = client.chat.completions.create(
        model="mistralai/mistral-small-3.2-24b-instruct:free",  # Or specify a specific model like "anthropic/claude-3-haiku"
        messages=[
            {"role": "user", "content": "What is the capital of Germany? (in German)"},
        ]
    )

    print(chat_completion.choices[0].message.content)

except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Die Hauptstadt von Deutschland ist Berlin.

# %%
# Example: Streaming responses
try:
    stream = client.chat.completions.create(
        model="mistralai/mistral-small-3.2-24b-instruct:free",
        messages=[
            {"role": "user", "content": "Tell me about Immanuel Kant."},
        ],
        stream=True
    )

    for chunk in stream:
        if chunk.choices[0].delta.content is not None:
            print(chunk.choices[0].delta.content, end="")
    print("\n")

except Exception as e:
    print(f"An error occurred during streaming: {e}")
# Out:
# Immanuel Kant (1724–1804) was a German philosopher who is one of the most influential figures in Western philosophy. He is best known for his work in epistemology, ethics, and aesthetics, and his ideas have had a profound impact on modern philosophy. Here are some key aspects of his life and work:
#
# ### **Life and Background**
# - Born on **April 22, 1724**, in Königsberg, Prussia (now Kaliningrad, Russia).
# - Spent his entire life in Königsberg, working as a professor of philosophy.
# - Died on **February 12, 1804**, in Königsberg.
#
# ### **Major Philosophical Works**
# 1. **"Critique of Pure Reason" (1781, 2nd ed. 1787)** – His most famous work, where he explores the limits of human reason and knowledge.
# 2. **"Groundwork of the Metaphysics of Morals" (1785)** – Introduces his moral philosophy, including the **Categorical Imperative**.
# 3. **"Critique of Practical Reason" (1788)** – Expands on his ethical theory.
# ...
